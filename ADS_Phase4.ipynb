# %% [markdown]
# ## Importing Necessary Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the Dataset

# %%
c_data = pd.read_csv(r"C:\Users\Admin\Downloads\country_vaccinations.csv")

# %% [markdown]
# ## Exploring the Dataset

# %%
c_data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
c_data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.360700e+04       4.129400e+04             3.880200e+04
# mean         4.592964e+07       1.770508e+07             1.413830e+07
# std          2.246004e+08       7.078731e+07             5.713920e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.264100e+05       3.494642e+05             2.439622e+05
# 50%          3.590096e+06       2.187310e+06             1.722140e+06
# 75%          1.701230e+07       9.152520e+06             7.559870e+06
# max          3.263129e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.536200e+04        8.621300e+04
# mean             2.705996e+05        1.313055e+05
# std              1.212427e+06        7.682388e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.668000e+03        9.000000e+02
# 50%              2.530900e+04        7.343000e+03
# 75%              1.234925e+05        4.409800e+04
# max              2.474100e+07        2.242429e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    43607.000000                   41294.000000
# mean                        80.188543                      40.927317
# std                         67.913577                      29.290759
# min                          0.000000                       0.000000
# 25%                         16.050000                      11.370000
# 50%                         67.520000                      41.435000
# 75%                        132.735000                      67.910000
# max                        345.370000                     124.760000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         38802.000000                    86213.000000
# mean                             35.523243                     3257.049157
# std                              28.376252                     3934.312440
# min                               0.000000                        0.000000
# 25%                               7.020000                      636.000000
# 50%                              31.750000                     2050.000000
# 75%                              62.080000                     4682.000000
# max                             122.370000                   117497.000000

# %%
c_data.shape
# Out:
# (86512, 15)

# %%
c_data.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     42905
# people_vaccinated                      45218
# people_fully_vaccinated                47710
# daily_vaccinations_raw                 51150
# daily_vaccinations                       299
# total_vaccinations_per_hundred         42905
# people_vaccinated_per_hundred          45218
# people_fully_vaccinated_per_hundred    47710
# daily_vaccinations_per_million           299
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %% [markdown]
# # Data Pre - Processing

# %%
#removing the missing values
c_data_cleaned = c_data.dropna()

c_data_cleaned.info()

c_data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30847 entries, 94 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              30847 non-null  object
#  1   iso_code                             30847 non-null  object
#  2   date                                 30847 non-null  object
#  3   total_vaccinations                   30847 non-null  float64
#  4   people_vaccinated                    30847 non-null  float64
#  5   people_fully_vaccinated              30847 non-null  float64
#  6   daily_vaccinations_raw               30847 non-null  float64
#  7   daily_vaccinations                   30847 non-null  float64
#  8   total_vaccinations_per_hundred       30847 non-null  float64
#  9   people_vaccinated_per_hundred        30847 non-null  float64
#  10  people_fully_vaccinated_per_hundred  30847 non-null  float64
#  11  daily_vaccinations_per_million       30847 non-null  float64
#  12  vaccines                             30847 non-null  object
#  13  source_name                          30847 non-null  object
#  14  source_website                       30847 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 3.8+ MB
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.084700e+04       3.084700e+04             3.084700e+04
# mean         3.980375e+07       2.177533e+07             1.579596e+07
# std          1.451667e+08       8.053173e+07             5.898165e+07
# min          3.000000e+00       3.000000e+00             1.000000e+00
# 25%          1.153332e+06       7.339795e+05             3.704450e+05
# 50%          6.335305e+06       3.688092e+06             2.211035e+06
# 75%          2.520629e+07       1.440668e+07             9.121526e+06
# max          3.243599e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.084700e+04        3.084700e+04
# mean             2.021875e+05        1.975297e+05
# std              7.041931e+05        6.400504e+05
# min              0.000000e+00        0.000000e+00
# 25%              5.498000e+03        7.329500e+03
# 50%              2.908100e+04        3.247200e+04
# 75%              1.344580e+05        1.402915e+05
# max              1.862727e+07        1.307071e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    30847.000000                   30847.000000
# mean                        88.609156                      44.793028
# std                         67.492111                      28.464379
# min                          0.000000                       0.000000
# 25%                         25.475000                      17.190000
# 50%                         81.470000                      48.160000
# 75%                        140.745000                      70.330000
# max                        345.370000                     124.760000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         30847.000000                    30847.000000
# mean                             36.563440                     4254.195708
# std                              28.532602                     3723.291475
# min                               0.000000                        0.000000
# 25%                               7.400000                     1567.500000
# 50%                              34.110000                     3254.000000
# 75%                              63.570000                     6069.500000
# max                             122.370000                    78604.000000

# %%
# Dropping source name and website from the data
c_data_new = c_data_cleaned.drop(['source_name','source_website'],axis = 1)
c_data_new.head()
# Out:
#          country iso_code        date  total_vaccinations  people_vaccinated  \
# 94   Afghanistan      AFG  2021-05-27            593313.0           479574.0
# 101  Afghanistan      AFG  2021-06-03            630305.0           481800.0
# 339  Afghanistan      AFG  2022-01-27           5081064.0          4517380.0
# 433      Albania      ALB  2021-02-18              3049.0             2438.0
# 515      Albania      ALB  2021-05-11            622507.0           440921.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 94                  113739.0                  2859.0              6487.0
# 101                 148505.0                  4015.0              5285.0
# 339                3868832.0                  6868.0              9802.0
# 433                    611.0                  1348.0               254.0
# 515                 181586.0                  9548.0             12160.0
#
#      total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 94                             1.49                           1.20
# 101                            1.58                           1.21
# 339                           12.76                          11.34
# 433                            0.11                           0.08
# 515                           21.67                          15.35
#
#      people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 94                                  0.29                           163.0
# 101                                 0.37                           133.0
# 339                                 9.71                           246.0
# 433                                 0.02                            88.0
# 515                                 6.32                          4233.0
#
#                                               vaccines
# 94   Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 339  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 433  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 515  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...

# %%
#Changing date column to date-type
c_data_new["date"] = pd.to_datetime(c_data_new["date"], format = '%Y-%m-%d')

# %%
#Reset index
c_data_new.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##### After Pre-processing our data looks like this

# %%
c_data_new.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-05-27            593313.0           479574.0
# 1  Afghanistan      AFG 2021-06-03            630305.0           481800.0
# 2  Afghanistan      AFG 2022-01-27           5081064.0          4517380.0
# 3      Albania      ALB 2021-02-18              3049.0             2438.0
# 4      Albania      ALB 2021-05-11            622507.0           440921.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                 113739.0                  2859.0              6487.0
# 1                 148505.0                  4015.0              5285.0
# 2                3868832.0                  6868.0              9802.0
# 3                    611.0                  1348.0               254.0
# 4                 181586.0                  9548.0             12160.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            1.49                           1.20
# 1                            1.58                           1.21
# 2                           12.76                          11.34
# 3                            0.11                           0.08
# 4                           21.67                          15.35
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                 0.29                           163.0
# 1                                 0.37                           133.0
# 2                                 9.71                           246.0
# 3                                 0.02                            88.0
# 4                                 6.32                          4233.0
#
#                                             vaccines
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...

# %% [markdown]
# ## Visualizations

# %%
#Total vaccinations over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=c_data_new, x='date', y='total_vaccinations')
plt.title('Total COVID 19 Vaccinations Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
#Daily vaccinations over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=c_data_new, x='date', y='daily_vaccinations')
plt.title('Daily COVID 19 Vaccinations Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
# Daily vaccinations over time for a specific country (e.g., India)
india_data = c_data_new[c_data_new['country'] == 'India']
plt.figure(figsize=(10, 6))
sns.lineplot(x='date', y='daily_vaccinations', data=india_data)
plt.title('Daily Vaccinations in India')
plt.xlabel('Date')
plt.ylabel('Daily Vaccinations')
plt.xticks(rotation=45)
plt.show()

# %%
#Total vaccinations by top 10 countries
total_vb_country = c_data_new.groupby('country').max().sort_values('total_vaccinations', ascending=False)
total_vb_country = total_vb_country.iloc[:10]

plt.figure(figsize=(16, 7))
plt.bar(total_vb_country.index, total_vb_country.total_vaccinations)

plt.title('Total vaccinations per country')
plt.xticks(rotation = 90)
plt.ylabel('Total vaccinations')
plt.xlabel('Country')
plt.show()

# %%
#Vaccinations per 100 for the top 10 countries

vb_country = c_data_new.groupby('country').max().sort_values('total_vaccinations', ascending=False)
vb_country = vb_country.iloc[:10]

vb_country = vb_country.sort_values('total_vaccinations_per_hundred', ascending=False)

plt.figure(figsize=(18, 6))
plt.bar(vb_country.index, vb_country.total_vaccinations_per_hundred)

plt.xticks(rotation = 90)
plt.title('Vaccinations per 100 for the top 10 Countries')
plt.ylabel('Vaccinations per 100')
plt.xlabel('Country')
plt.show()

# %%
#No. of people vaccinated and fully vaccinated
selected_countries = ['China', 'India', 'Japan', 'United States','Brazil']  

filtered_data = c_data_new[c_data_new['country'].isin(selected_countries)]

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='people_vaccinated', y='country', data=filtered_data, label='People Vaccinated', color='skyblue')
sns.barplot(x='people_fully_vaccinated', y='country', data=filtered_data, label='People Fully Vaccinated', color='lightcoral')
plt.title('People Vaccinated vs People Fully Vaccinated by Country')
plt.xlabel('Number of People')
plt.ylabel('Country')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
#No. of people vaccinated and fully vaccinated per hundred
selected_countries = ['China', 'India', 'Japan', 'United States','Brazil']  

filtered_data = c_data_new[c_data_new['country'].isin(selected_countries)]

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='people_vaccinated_per_hundred', y='country', data=filtered_data, label='People Vaccinated', color='limegreen')
sns.barplot(x='people_fully_vaccinated_per_hundred', y='country', data=filtered_data, label='People Fully Vaccinated', color='skyblue')
plt.title('People Vaccinated Per Hundred vs People Fully Vaccinated Per Hundred  by Country')
plt.xlabel('Number of People')
plt.ylabel('Country')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
#Vaccinations per million for the top 10 countries
t10_countries = c_data_new.groupby('country').max().sort_values('daily_vaccinations_per_million', ascending=False)
t10_countries = t10_countries.iloc[0:10]

t10_countries = t10_countries.sort_values('daily_vaccinations_per_million',ascending = False)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(t10_countries.index, t10_countries.daily_vaccinations_per_million, color = 'lightgreen')
plt.title('Top 10 Countries by Total Vaccinations Per Million')
plt.xlabel('Total Vaccinations per Million')
plt.ylabel('Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Statistical analysis

# %%
# Calculate the statistics
median = c_data_new.median()
variance =c_data_new.var()
standard_deviation = c_data_new.std()
skewness =c_data_new.skew()
kurtosis = c_data_new.kurtosis()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   median = c_data_new.median()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median = c_data_new.median()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   variance =c_data_new.var()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   standard_deviation = c_data_new.std()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:5: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness =c_data_new.skew()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7256\3442266086.py:6: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kurtosis = c_data_new.kurtosis()

# %% [markdown]
# ### Plotting the statistics

# %%
# Median
plt.figure(figsize=(95, 35))
plt.subplot(2, 3, 1)
plt.scatter(median.index, median,color='darkslategray')
plt.title('Median')
for i, v in enumerate(median):
    plt.text(i, v, f'{v:.2f}', ha='right', va='bottom', fontsize=10)
plt.show()

print(median)
# Out:
# total_vaccinations                     6335305.00
# people_vaccinated                      3688092.00
# people_fully_vaccinated                2211035.00
# daily_vaccinations_raw                   29081.00
# daily_vaccinations                       32472.00
# total_vaccinations_per_hundred              81.47
# people_vaccinated_per_hundred               48.16
# people_fully_vaccinated_per_hundred         34.11
# daily_vaccinations_per_million            3254.00
# dtype: float64

# %%
#Variance
plt.figure(figsize=(95, 35))
plt.subplot(2, 3, 2)
plt.scatter(variance.index, variance,color='darkslategray')
plt.title('Variance')
for i, v in enumerate(variance):
    plt.text(i, v, f'{v:.2f}', ha='right', va='bottom', fontsize=10)
plt.show()

print(variance)
# Out:
# total_vaccinations                     2.107337e+16
# people_vaccinated                      6.485359e+15
# people_fully_vaccinated                3.478835e+15
# daily_vaccinations_raw                 4.958879e+11
# daily_vaccinations                     4.096645e+11
# total_vaccinations_per_hundred         4.555185e+03
# people_vaccinated_per_hundred          8.102208e+02
# people_fully_vaccinated_per_hundred    8.141094e+02
# daily_vaccinations_per_million         1.386290e+07
# dtype: float64

# %%
#Standard Deviation
print(standard_deviation)
# Out:
# date                                   118 days 21:36:36.430318214
# total_vaccinations                                145166710.124079
# people_vaccinated                                  80531727.485225
# people_fully_vaccinated                            58981646.564469
# daily_vaccinations_raw                               704193.090561
# daily_vaccinations                                   640050.392748
# total_vaccinations_per_hundred                           67.492111
# people_vaccinated_per_hundred                            28.464379
# people_fully_vaccinated_per_hundred                      28.532602
# daily_vaccinations_per_million                         3723.291475
# dtype: object

# %%
# Skewness
plt.figure(figsize =(95,35))
plt.subplot(2, 3, 4)
plt.scatter(skewness.index, skewness, color ='darkslategray')
plt.title('Skewness')
for i, v in enumerate(skewness):
    plt.text(i, v, f'{v:.2f}', ha='right', va='bottom', fontsize=10)
plt.show()

print(skewness)
# Out:
# total_vaccinations                     10.516201
# people_vaccinated                       9.241404
# people_fully_vaccinated                11.105354
# daily_vaccinations_raw                 10.091944
# daily_vaccinations                      8.464592
# total_vaccinations_per_hundred          0.445244
# people_vaccinated_per_hundred          -0.097427
# people_fully_vaccinated_per_hundred     0.189611
# daily_vaccinations_per_million          2.916800
# dtype: float64

# %%
# Kurtosis
plt.figure(figsize=(95,35))
plt.subplot(2, 3, 5)
plt.scatter(kurtosis.index, kurtosis,color='darkslategray')
plt.title('Kurtosis')
for i, v in enumerate(kurtosis):
    plt.text(i, v, f'{v:.2f}', ha='right', va='bottom', fontsize=10)
plt.show()

print(kurtosis)
# Out:
# total_vaccinations                     147.346479
# people_vaccinated                      100.462194
# people_fully_vaccinated                160.119507
# daily_vaccinations_raw                 141.108822
# daily_vaccinations                      89.783719
# total_vaccinations_per_hundred          -0.696450
# people_vaccinated_per_hundred           -1.273631
# people_fully_vaccinated_per_hundred     -1.324171
# daily_vaccinations_per_million          29.063756
# dtype: float64
